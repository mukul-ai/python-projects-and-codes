# %%
def welcome():
    print("Welcome in MyBank")
    autho()
    
def autho():
    flag=True
    pin=1234
    count=3
    while(flag):
        #print("Enter Your Pin")
        try:
            upin=int(input("Enter the pin : "))
        except:
            print("pls enter the ATM pin correctly")
        else:
            if(upin==pin):
                print("Succesfull")
                flag=False
                result=True
                menu(result)
            else:
                print("wronge pin")
                count=count-1
                print("current count is ", count)
                if(count==0):
                    flag=False
                    result=False
    return result

  
def cardblock(result):
    if result==False:
        print("card is Blocked")
        
        
balance=15000        
def menu(result):
    global balance
    while result:
            print("1.Deposite")
            print("2.Widthral")
            print("3.Balance")
            print("4.pin change")
            print("5.Exit")
            try:
                response = int(input("Enter the response" ))
            
            except:
                print("pls enter the correct response")
                
            else:
                if response==1:
                    print("Enter the amount to deposite")
                    depo=int(input())
                    balance = balance + depo
                    print("Current balance is",balance)
                elif response==2:
                    print("Enter the amount to withdral")
                    withdral=int(input())
                    balance = balance - withdral
                    print("Current balance is",balance)
                elif response==3:
                    print("Current balance is",balance)
                elif response==4:
                    print("Enter new Pin")
                    upin=int(input())
                elif response==5:
                    print("Thank you for coming SBI ATM")
                    result=False

        


        
welcome()
#y=autho()
#cardblock(y)
#x=menu(y)
# Out:
# Welcome in MyBank
# Enter the pin :  jffygjhhjh
# pls enter the ATM pin correctly
# Enter the pin :  1234
# Succesfull
# 1.Deposite
# 2.Widthral
# 3.Balance
# 4.pin change
# 5.Exit

# %%
def hotal():
    print("welcome to Taj")
    menu()
    
    
def menu():
        print("1. for Vag")
        print("2. for non veg")
        print("3. for snakes")
        print("4. for bill")
        try:
            opt= int(input("enter the option: "))
        except:
            print("pls enter the correct input")
        else:
            card(opt)
    
def card(opt):
    flag = True
    while flag:
        print("1. for Vag")
        print("2. for non veg")
        print("3. for snakes")
        print("4. for bill")
        if(opt==1):
            print("Veg dishes")
            
            dish_name = input("Enter the dish name")
            veg(dish_name)
        elif(opt ==2):
            print("All Non-veg dishes")
            dish_name= input("Enter the dish name")
            non_veg(dish_name)
        elif(opt ==4):
            print("Thank you")
            result = False
            final_bill()
        
        
def veg(dish_name):
    if(dish_name == "Rice"):
        print("your order is preparing")
        quanty = int(input("enter the quantity"))
        price = int(input("enter the price"))   
        bill(price, quanty)
    elif(dish_name == "Paneer"):
        print("your order is preparing")
        quanty = int(input("enter the quantity"))
        price = int(input("enter the price"))   
        bill(price, quanty)
    elif(dish_name =="Dal"):
        print("your order is preparing")
        quanty = int(input("enter the quantity"))
        price = int(input("enter the price"))   
        bill(price, quanty)
    elif(dish_name == " "):
        print("your order is preparing")
        quanty = int(input("enter the quantity"))
        price = int(input("enter the price"))   
        bill(price, quanty)
        
def non_veg(dish_name):
    if(dish_name == "Chiken"):
        print("your order is preparing")
        price = int(input("enter the price"))
        quanty = int(input("enter the quantity"))
        bill(price, quanty)
    
Bill = 0   
def bill(price, quanty):
    global Bill
    Bill = Bill +(price*quanty)
    final_bill(Bill)

    
def final_bill(result):
    print("Your Bill is ", Bill)
    print("Thank you for Visiting our place")

# %%
hotal()
# Out:
# welcome to Taj
# 1. for Vag
# 2. for non veg
# 3. for snakes
# 4. for bill
# enter the option: 1
# 1. for Vag
# 2. for non veg
# 3. for snakes
# 4. for bill
# Veg dishes
# Enter the dish name
# 1. for Vag
# 2. for non veg
# 3. for snakes
# 4. for bill
# Veg dishes
# Enter the dish name
# 1. for Vag
# 2. for non veg
# 3. for snakes
# 4. for bill
# Veg dishes

# %% [markdown]
# ####
